# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
data = pd.read_csv("chainlink.csv")
data.head()
# Out:
#           x         y         z  class
# 0 -0.452525 -0.890705  0.023005      1
# 1  0.652850 -0.845875  0.021084      1
# 2  0.397904  0.913450 -0.001391      1
# 3  0.095233  1.054986  0.006280      1
# 4  0.523990 -0.941104  0.037762      1

# %%
x = data.drop("class" , axis=1)
y = data["class"]

# %%
# %matplotlib qt
ax = plt.axes(projection = "3d")
ax.scatter3D(x["x"] , x["y"] , x["z"] , c=y)

# %%
x_train , x_test , y_train , y_test = train_test_split(
    x , y , test_size=0.2 , random_state=159
)

# %%
svc = SVC(kernel="linear")
svc.fit(x_train , y_train)
y_pred = svc.predict(x_test)

# %% [markdown]
# trying out the rbf kernel:

# %%
model = SVC(kernel="rbf")
model.fit(x_train , y_train)
res = model.predict(x_test)

# %%
# %matplotlib qt
ax = plt.axes(projection = "3d")
ax.scatter3D(x_test["x"] , x_test["y"] , x_test["z"] , c=res)
